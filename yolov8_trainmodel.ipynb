# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Install YOLOv8
#
# ⚠️ YOLOv8 is still under heavy development. Breaking changes are being introduced almost weekly. We strive to make our YOLOv8 notebooks work with the latest version of the library. Last tests took place on **27.01.2023** with version **YOLOv8.0.20**.
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.
#
# YOLOv8 can be installed in two ways - from the source and via pip. This is because it is the first iteration of YOLO to have an official package.

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.20
# !pip install albumentations==1.4

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (8 CPUs, 51.0 GB RAM, 29.2/235.7 GB disk)

# %%
# Git clone method (for development)

# %cd {HOME}
# !git clone github.com/ultralytics/ultralytics
# %cd {HOME}/ultralytics
# !pip install -qe ultralytics

# from IPython import display
# display.clear_output()

# import ultralytics
# ultralytics.checks()

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ## CLI Basics

# %% [markdown]
# If you want to train, validate or run inference on models and don't need to make any modifications to the code, using YOLO command line interface is the easiest way to get started. Read more about CLI in [Ultralytics YOLO Docs](https://v8docs.ultralytics.com/cli/).
#
# ```
# yolo task=detect    mode=train    model=yolov8n.yaml      args...
#           classify       predict        yolov8n-cls.yaml  args...
#           segment        val            yolov8n-seg.yaml  args...
#                          export         yolov8n.pt        format=onnx  args...
# ```

# %% [markdown]
# ## Inference with Pre-trained COCO Model

# %% [markdown]
# ### 💻 CLI

# %% [markdown]
# `yolo mode=predict` runs YOLOv8 inference on a variety of sources, downloading models automatically from the latest YOLOv8 release, and saving results to `runs/predict`.

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to yolov8n.pt...
# 100% 6.23M/6.23M [00:00<00:00, 208MB/s]
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py:332: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(file, map_location='cpu')  # load
# 2024-10-16 09:25:07.695977: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-16 09:25:07.715923: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-16 09:25:07.721817: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-16 09:25:07.736310: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-16 09:25:08.926196: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# Downloading https://media.roboflow.com/notebooks/examples/dog.jpeg to dog.jpeg...
# 100% 104k/104k [00:00<00:00, 69.3MB/s]
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 65.7ms
# Speed: 0.6ms pre-process, 65.7ms inference, 852.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
# 'Colab Notebooks'   dataset-2.zip      datasetอันเก่า.zip		  images      weight
#  Dataset	    Dataset2.zip       Dog_vs_Cat		 'My Drive'   weights.zip
#  dataset_01.zip     dataset.mov        first-order-motion-model   project     สุดๆเเล้วดาต้า.zip
#  dataset-1.mov	    dataset.zip        flower			  Project
#  dataset1.zip	    datasetรูปน้อย.zip   flower2			  Project1

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !unzip /content/gdrive/MyDrive/dataset1.zip
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
#   inflating: dataset1/images/validation/602_person.jpg
#   inflating: dataset1/images/validation/602_person.txt
#   inflating: dataset1/images/validation/603_person.jpg
#   inflating: dataset1/images/validation/603_person.txt
#   inflating: dataset1/images/validation/604_person.jpg
#   inflating: dataset1/images/validation/604_person.txt
#   inflating: dataset1/images/validation/605_person.jpg
#   inflating: dataset1/images/validation/605_person.txt
#   inflating: dataset1/images/validation/606_person.jpg
#   inflating: dataset1/images/validation/606_person.txt
#   inflating: dataset1/images/validation/607_person.jpg
#   inflating: dataset1/images/validation/607_person.txt
#   inflating: dataset1/images/validation/608_person.jpg
#   inflating: dataset1/images/validation/608_person.txt
#   inflating: dataset1/images/validation/609_person.jpg
#   inflating: dataset1/images/validation/609_person.txt
#   inflating: dataset1/images/validation/60_person.jpg
#   inflating: dataset1/images/validation/60_person.txt
#   inflating: dataset1/images/validation/610_person.jpg
#   inflating: dataset1/images/validation/610_person.txt
#   inflating: dataset1/images/validation/611_person.jpg
#   inflating: dataset1/images/validation/611_person.txt
#   inflating: dataset1/images/validation/612_person.jpg
#   inflating: dataset1/images/validation/612_person.txt
#   inflating: dataset1/images/validation/613_person.jpg
#   inflating: dataset1/images/validation/613_person.txt
#   inflating: dataset1/images/validation/614_person.jpg
#   inflating: dataset1/images/validation/614_person.txt
#   inflating: dataset1/images/validation/615_person.jpg
#   inflating: dataset1/images/validation/615_person.txt
#   inflating: dataset1/images/validation/616_person.jpg
#   inflating: dataset1/images/validation/616_person.txt
#   inflating: dataset1/images/validation/617_person.jpg
#   inflating: dataset1/images/validation/617_person.txt
#   inflating: dataset1/images/validation/618_person.jpg
#   inflating: dataset1/images/validation/618_person.txt
#   inflating: dataset1/images/validation/619_person.jpg
#   inflating: dataset1/images/validation/619_person.txt
#   inflating: dataset1/images/validation/61_person.jpg
#   inflating: dataset1/images/validation/61_person.txt
#   inflating: dataset1/images/validation/620_person.jpg
#   inflating: dataset1/images/validation/620_person.txt
#   inflating: dataset1/images/validation/621_person.jpg
#   inflating: dataset1/images/validation/621_person.txt
#   inflating: dataset1/images/validation/622_person.jpg
#   inflating: dataset1/images/validation/622_person.txt
#   inflating: dataset1/images/validation/623_person.jpg
#   inflating: dataset1/images/validation/623_person.txt
#   inflating: dataset1/images/validation/624_person.jpg
#   inflating: dataset1/images/validation/624_person.txt
#   inflating: dataset1/images/validation/625_person.jpg
#   inflating: dataset1/images/validation/625_person.txt
#   inflating: dataset1/images/validation/626_person.jpg
#   inflating: dataset1/images/validation/626_person.txt
#   inflating: dataset1/images/validation/627_person.jpg
#   inflating: dataset1/images/validation/627_person.txt
#   inflating: dataset1/images/validation/628_person.jpg
#   inflating: dataset1/images/validation/628_person.txt
#   inflating: dataset1/images/validation/629_person.jpg
#   inflating: dataset1/images/validation/629_person.txt
#   inflating: dataset1/images/validation/62_person.jpg
#   inflating: dataset1/images/validation/62_person.txt
#   inflating: dataset1/images/validation/630_person.jpg
#   inflating: dataset1/images/validation/630_person.txt
#   inflating: dataset1/images/validation/631_person.jpg
#   inflating: dataset1/images/validation/631_person.txt
#   inflating: dataset1/images/validation/632_person.jpg
#   inflating: dataset1/images/validation/632_person.txt
#   inflating: dataset1/images/validation/633_person.jpg
#   inflating: dataset1/images/validation/633_person.txt
#   inflating: dataset1/images/validation/634_person.jpg
#   inflating: dataset1/images/validation/634_person.txt
#   inflating: dataset1/images/validation/635_person.jpg
#   inflating: dataset1/images/validation/635_person.txt
#   inflating: dataset1/images/validation/636_person.jpg
#   inflating: dataset1/images/validation/636_person.txt
#   inflating: dataset1/images/validation/637_person.jpg
#   inflating: dataset1/images/validation/637_person.txt
#   inflating: dataset1/images/validation/638_person.jpg
#   inflating: dataset1/images/validation/638_person.txt
#   inflating: dataset1/images/validation/639_person.jpg
#   inflating: dataset1/images/validation/639_person.txt
#   inflating: dataset1/images/validation/63_person.jpg
#   inflating: dataset1/images/validation/63_person.txt
#   inflating: dataset1/images/validation/640_person.jpg
#   inflating: dataset1/images/validation/640_person.txt
#   inflating: dataset1/images/validation/641_person.jpg
#   inflating: dataset1/images/validation/641_person.txt
#   inflating: dataset1/images/validation/642_person.jpg
#   inflating: dataset1/images/validation/642_person.txt
#   inflating: dataset1/images/validation/643_person.jpg
#   inflating: dataset1/images/validation/643_person.txt
#   inflating: dataset1/images/validation/644_person.jpg
#   inflating: dataset1/images/validation/644_person.txt
#   inflating: dataset1/images/validation/645_person.jpg
#   inflating: dataset1/images/validation/645_person.txt
#   inflating: dataset1/images/validation/646_person.jpg
#   inflating: dataset1/images/validation/646_person.txt
#   inflating: dataset1/images/validation/647_person.jpg
#   inflating: dataset1/images/validation/647_person.txt
#   inflating: dataset1/images/validation/648_person.jpg
#   inflating: dataset1/images/validation/648_person.txt
#   inflating: dataset1/images/validation/649_person.jpg
#   inflating: dataset1/images/validation/649_person.txt
#   inflating: dataset1/images/validation/64_person.jpg
#   inflating: dataset1/images/validation/64_person.txt
#   inflating: dataset1/images/validation/650_person.jpg
#   inflating: dataset1/images/validation/650_person.txt
#   inflating: dataset1/images/validation/651_person.jpg
#   inflating: dataset1/images/validation/651_person.txt
#   inflating: dataset1/images/validation/652_person.jpg
#   inflating: dataset1/images/validation/652_person.txt
#   inflating: dataset1/images/validation/653_person.jpg
#   inflating: dataset1/images/validation/653_person.txt
#   inflating: dataset1/images/validation/654_person.jpg
#   inflating: dataset1/images/validation/654_person.txt
#   inflating: dataset1/images/validation/655_person.jpg
#   inflating: dataset1/images/validation/655_person.txt
#   inflating: dataset1/images/validation/656_person.jpg
#   inflating: dataset1/images/validation/656_person.txt
#   inflating: dataset1/images/validation/657_person.jpg
#   inflating: dataset1/images/validation/657_person.txt
#   inflating: dataset1/images/validation/658_person.jpg
#   inflating: dataset1/images/validation/658_person.txt
#   inflating: dataset1/images/validation/659_person.jpg
#   inflating: dataset1/images/validation/659_person.txt
#   inflating: dataset1/images/validation/65_person.jpg
#   inflating: dataset1/images/validation/65_person.txt
#   inflating: dataset1/images/validation/660_person.jpg
#   inflating: dataset1/images/validation/660_person.txt
#   inflating: dataset1/images/validation/661_person.jpg
#   inflating: dataset1/images/validation/661_person.txt
#   inflating: dataset1/images/validation/662_person.jpg
#   inflating: dataset1/images/validation/662_person.txt
#   inflating: dataset1/images/validation/663_person.jpg
#   inflating: dataset1/images/validation/663_person.txt
#   inflating: dataset1/images/validation/664_person.jpg
#   inflating: dataset1/images/validation/664_person.txt
#   inflating: dataset1/images/validation/665_person.jpg
#   inflating: dataset1/images/validation/665_person.txt
#   inflating: dataset1/images/validation/666_person.jpg
#   inflating: dataset1/images/validation/666_person.txt
#   inflating: dataset1/images/validation/667_person.jpg
#   inflating: dataset1/images/validation/667_person.txt
#   inflating: dataset1/images/validation/668_person.jpg
#   inflating: dataset1/images/validation/668_person.txt
#   inflating: dataset1/images/validation/669_person.jpg
#   inflating: dataset1/images/validation/669_person.txt
#   inflating: dataset1/images/validation/66_person.jpg
#   inflating: dataset1/images/validation/66_person.txt
#   inflating: dataset1/images/validation/670_person.jpg
#   inflating: dataset1/images/validation/670_person.txt
#   inflating: dataset1/images/validation/671_person.jpg
#   inflating: dataset1/images/validation/671_person.txt
#   inflating: dataset1/images/validation/672_person.jpg
#   inflating: dataset1/images/validation/672_person.txt
#   inflating: dataset1/images/validation/673_person.jpg
#   inflating: dataset1/images/validation/673_person.txt
#   inflating: dataset1/images/validation/674_person.jpg
#   inflating: dataset1/images/validation/674_person.txt
#   inflating: dataset1/images/validation/675_person.jpg
#   inflating: dataset1/images/validation/676_person.jpg
#   inflating: dataset1/images/validation/676_person.txt
#   inflating: dataset1/images/validation/677_person.jpg
#   inflating: dataset1/images/validation/677_person.txt
#   inflating: dataset1/images/validation/678_person.jpg
#   inflating: dataset1/images/validation/678_person.txt
#   inflating: dataset1/images/validation/679_person.jpg
#   inflating: dataset1/images/validation/679_person.txt
#   inflating: dataset1/images/validation/67_person.jpg
#   inflating: dataset1/images/validation/67_person.txt
#   inflating: dataset1/images/validation/680_person.jpg
#   inflating: dataset1/images/validation/680_person.txt
#   inflating: dataset1/images/validation/681_person.jpg
#   inflating: dataset1/images/validation/681_person.txt
#   inflating: dataset1/images/validation/682_person.jpg
#   inflating: dataset1/images/validation/682_person.txt
#   inflating: dataset1/images/validation/683_person.jpg
#   inflating: dataset1/images/validation/683_person.txt
#   inflating: dataset1/images/validation/684_person.jpg
#   inflating: dataset1/images/validation/684_person.txt
#   inflating: dataset1/images/validation/685_person.jpg
#   inflating: dataset1/images/validation/686_person.jpg
#   inflating: dataset1/images/validation/686_person.txt
#   inflating: dataset1/images/validation/687_person.jpg
#   inflating: dataset1/images/validation/687_person.txt
#   inflating: dataset1/images/validation/688_person.jpg
#   inflating: dataset1/images/validation/688_person.txt
#   inflating: dataset1/images/validation/689_person.jpg
#   inflating: dataset1/images/validation/689_person.txt
#   inflating: dataset1/images/validation/68_person.jpg
#   inflating: dataset1/images/validation/68_person.txt
#   inflating: dataset1/images/validation/690_person.jpg
#   inflating: dataset1/images/validation/690_person.txt
#   inflating: dataset1/images/validation/691_person.jpg
#   inflating: dataset1/images/validation/691_person.txt
#   inflating: dataset1/images/validation/692_person.jpg
#   inflating: dataset1/images/validation/692_person.txt
#   inflating: dataset1/images/validation/693_person.jpg
#   inflating: dataset1/images/validation/693_person.txt
#   inflating: dataset1/images/validation/694_person.jpg
#   inflating: dataset1/images/validation/694_person.txt
#   inflating: dataset1/images/validation/695_person.jpg
#   inflating: dataset1/images/validation/695_person.txt
#   inflating: dataset1/images/validation/696_person.jpg
#   inflating: dataset1/images/validation/696_person.txt
#   inflating: dataset1/images/validation/697_person.jpg
#   inflating: dataset1/images/validation/697_person.txt
#   inflating: dataset1/images/validation/698_person.jpg
#   inflating: dataset1/images/validation/698_person.txt
#   inflating: dataset1/images/validation/699_person.jpg
#   inflating: dataset1/images/validation/699_person.txt
#   inflating: dataset1/images/validation/69_person.jpg
#   inflating: dataset1/images/validation/6_person.jpg
#   inflating: dataset1/images/validation/6_person.txt
#   inflating: dataset1/images/validation/700_person.jpg
#   inflating: dataset1/images/validation/700_person.txt
#   inflating: dataset1/images/validation/701_person.jpg
#   inflating: dataset1/images/validation/701_person.txt
#   inflating: dataset1/images/validation/702_person.jpg
#   inflating: dataset1/images/validation/702_person.txt
#   inflating: dataset1/images/validation/703_person.jpg
#   inflating: dataset1/images/validation/703_person.txt
#   inflating: dataset1/images/validation/704_person.jpg
#   inflating: dataset1/images/validation/704_person.txt
#   inflating: dataset1/images/validation/705_person.jpg
#   inflating: dataset1/images/validation/705_person.txt
#   inflating: dataset1/images/validation/706_person.jpg
#   inflating: dataset1/images/validation/706_person.txt
#   inflating: dataset1/images/validation/707_person.jpg
#   inflating: dataset1/images/validation/707_person.txt
#   inflating: dataset1/images/validation/708_person.jpg
#   inflating: dataset1/images/validation/708_person.txt
#   inflating: dataset1/images/validation/709_person.jpg
#   inflating: dataset1/images/validation/709_person.txt
#   inflating: dataset1/images/validation/70_person.jpg
#   inflating: dataset1/images/validation/70_person.txt
#   inflating: dataset1/images/validation/710_person.jpg
#   inflating: dataset1/images/validation/710_person.txt
#   inflating: dataset1/images/validation/711_person.jpg
#   inflating: dataset1/images/validation/711_person.txt
#   inflating: dataset1/images/validation/712_person.jpg
#   inflating: dataset1/images/validation/712_person.txt
#   inflating: dataset1/images/validation/713_person.jpg
#   inflating: dataset1/images/validation/713_person.txt
#   inflating: dataset1/images/validation/714_person.jpg
#   inflating: dataset1/images/validation/714_person.txt
#   inflating: dataset1/images/validation/715_person.jpg
#   inflating: dataset1/images/validation/715_person.txt
#   inflating: dataset1/images/validation/716_person.jpg
#   inflating: dataset1/images/validation/716_person.txt
#   inflating: dataset1/images/validation/717_person.jpg
#   inflating: dataset1/images/validation/717_person.txt
#   inflating: dataset1/images/validation/718_person.jpg
#   inflating: dataset1/images/validation/719_person.jpg
#   inflating: dataset1/images/validation/719_person.txt
#   inflating: dataset1/images/validation/71_person.jpg
#   inflating: dataset1/images/validation/71_person.txt
#   inflating: dataset1/images/validation/720_person.jpg
#   inflating: dataset1/images/validation/720_person.txt
#   inflating: dataset1/images/validation/721_person.jpg
#   inflating: dataset1/images/validation/721_person.txt
#   inflating: dataset1/images/validation/722_person.jpg
#   inflating: dataset1/images/validation/722_person.txt
#   inflating: dataset1/images/validation/723_person.jpg
#   inflating: dataset1/images/validation/723_person.txt
#   inflating: dataset1/images/validation/724_person.jpg
#   inflating: dataset1/images/validation/724_person.txt
#   inflating: dataset1/images/validation/725_person.jpg
#   inflating: dataset1/images/validation/725_person.txt
#   inflating: dataset1/images/validation/726_person.jpg
#   inflating: dataset1/images/validation/726_person.txt
#   inflating: dataset1/images/validation/727_person.jpg
#   inflating: dataset1/images/validation/727_person.txt
#   inflating: dataset1/images/validation/728_person.jpg
#   inflating: dataset1/images/validation/728_person.txt
#   inflating: dataset1/images/validation/729_person.jpg
#   inflating: dataset1/images/validation/72_person.jpg
#   inflating: dataset1/images/validation/72_person.txt
#   inflating: dataset1/images/validation/730_person.jpg
#   inflating: dataset1/images/validation/730_person.txt
#   inflating: dataset1/images/validation/731_person.jpg
#   inflating: dataset1/images/validation/731_person.txt
#   inflating: dataset1/images/validation/732_person.jpg
#   inflating: dataset1/images/validation/732_person.txt
#   inflating: dataset1/images/validation/733_person.jpg
#   inflating: dataset1/images/validation/733_person.txt
#   inflating: dataset1/images/validation/734_person.jpg
#   inflating: dataset1/images/validation/734_person.txt
#   inflating: dataset1/images/validation/735_person.jpg
#   inflating: dataset1/images/validation/735_person.txt
#   inflating: dataset1/images/validation/736_person.jpg
#   inflating: dataset1/images/validation/736_person.txt
#   inflating: dataset1/images/validation/737_person.jpg
#   inflating: dataset1/images/validation/737_person.txt
#   inflating: dataset1/images/validation/738_person.jpg
#   inflating: dataset1/images/validation/738_person.txt
#   inflating: dataset1/images/validation/739_person.jpg
#   inflating: dataset1/images/validation/73_person.jpg
#   inflating: dataset1/images/validation/73_person.txt
#   inflating: dataset1/images/validation/740_person.jpg
#   inflating: dataset1/images/validation/740_person.txt
#   inflating: dataset1/images/validation/741_person.jpg
#   inflating: dataset1/images/validation/741_person.txt
#   inflating: dataset1/images/validation/742_person.jpg
#   inflating: dataset1/images/validation/743_person.jpg
#   inflating: dataset1/images/validation/743_person.txt
#   inflating: dataset1/images/validation/744_person.jpg
#   inflating: dataset1/images/validation/744_person.txt
#   inflating: dataset1/images/validation/745_person.jpg
#   inflating: dataset1/images/validation/746_person.jpg
#   inflating: dataset1/images/validation/746_person.txt
#   inflating: dataset1/images/validation/747_person.jpg
#   inflating: dataset1/images/validation/747_person.txt
#   inflating: dataset1/images/validation/748_person.jpg
#   inflating: dataset1/images/validation/748_person.txt
#   inflating: dataset1/images/validation/749_person.jpg
#   inflating: dataset1/images/validation/749_person.txt
#   inflating: dataset1/images/validation/74_person.jpg
#   inflating: dataset1/images/validation/74_person.txt
#   inflating: dataset1/images/validation/750_person.jpg
#   inflating: dataset1/images/validation/750_person.txt
#   inflating: dataset1/images/validation/751_person.jpg
#   inflating: dataset1/images/validation/751_person.txt
#   inflating: dataset1/images/validation/752_person.jpg
#   inflating: dataset1/images/validation/752_person.txt
#   inflating: dataset1/images/validation/753_person.jpg
#   inflating: dataset1/images/validation/753_person.txt
#   inflating: dataset1/images/validation/754_person.jpg
#   inflating: dataset1/images/validation/754_person.txt
#   inflating: dataset1/images/validation/755_person.jpg
#   inflating: dataset1/images/validation/755_person.txt
#   inflating: dataset1/images/validation/756_person.jpg
#   inflating: dataset1/images/validation/756_person.txt
#   inflating: dataset1/images/validation/757_person.jpg
#   inflating: dataset1/images/validation/757_person.txt
#   inflating: dataset1/images/validation/758_person.jpg
#   inflating: dataset1/images/validation/758_person.txt
#   inflating: dataset1/images/validation/759_person.jpg
#   inflating: dataset1/images/validation/759_person.txt
#   inflating: dataset1/images/validation/75_person.jpg
#   inflating: dataset1/images/validation/75_person.txt
#   inflating: dataset1/images/validation/760_person.jpg
#   inflating: dataset1/images/validation/760_person.txt
#   inflating: dataset1/images/validation/761_person.jpg
#   inflating: dataset1/images/validation/761_person.txt
#   inflating: dataset1/images/validation/762_person.jpg
#   inflating: dataset1/images/validation/762_person.txt
#   inflating: dataset1/images/validation/763_person.jpg
#   inflating: dataset1/images/validation/763_person.txt
#   inflating: dataset1/images/validation/764_person.jpg
#   inflating: dataset1/images/validation/764_person.txt
#   inflating: dataset1/images/validation/765_person.jpg
#   inflating: dataset1/images/validation/765_person.txt
#   inflating: dataset1/images/validation/766_person.jpg
#   inflating: dataset1/images/validation/766_person.txt
#   inflating: dataset1/images/validation/767_person.jpg
#   inflating: dataset1/images/validation/767_person.txt
#   inflating: dataset1/images/validation/768_person.jpg
#   inflating: dataset1/images/validation/768_person.txt
#   inflating: dataset1/images/validation/769_person.jpg
#   inflating: dataset1/images/validation/769_person.txt
#   inflating: dataset1/images/validation/76_person.jpg
#   inflating: dataset1/images/validation/76_person.txt
#   inflating: dataset1/images/validation/770_person.jpg
#   inflating: dataset1/images/validation/770_person.txt
#   inflating: dataset1/images/validation/771_person.jpg
#   inflating: dataset1/images/validation/771_person.txt
#   inflating: dataset1/images/validation/772_person.jpg
#   inflating: dataset1/images/validation/772_person.txt
#   inflating: dataset1/images/validation/773_person.jpg
#   inflating: dataset1/images/validation/773_person.txt
#   inflating: dataset1/images/validation/774_person.jpg
#   inflating: dataset1/images/validation/774_person.txt
#   inflating: dataset1/images/validation/775_person.jpg
#   inflating: dataset1/images/validation/775_person.txt
#   inflating: dataset1/images/validation/776_person.jpg
#   inflating: dataset1/images/validation/776_person.txt
#   inflating: dataset1/images/validation/777_person.jpg
#   inflating: dataset1/images/validation/777_person.txt
#   inflating: dataset1/images/validation/778_person.jpg
#   inflating: dataset1/images/validation/778_person.txt
#   inflating: dataset1/images/validation/779_person.jpg
#   inflating: dataset1/images/validation/779_person.txt
#   inflating: dataset1/images/validation/77_person.jpg
#   inflating: dataset1/images/validation/77_person.txt
#   inflating: dataset1/images/validation/780_person.jpg
#   inflating: dataset1/images/validation/780_person.txt
#   inflating: dataset1/images/validation/781_person.jpg
#   inflating: dataset1/images/validation/781_person.txt
#   inflating: dataset1/images/validation/782_person.jpg
#   inflating: dataset1/images/validation/782_person.txt
#   inflating: dataset1/images/validation/783_person.jpg
#   inflating: dataset1/images/validation/783_person.txt
#   inflating: dataset1/images/validation/784_person.jpg
#   inflating: dataset1/images/validation/784_person.txt
#   inflating: dataset1/images/validation/785_person.jpg
#   inflating: dataset1/images/validation/785_person.txt
#   inflating: dataset1/images/validation/786_person.jpg
#   inflating: dataset1/images/validation/786_person.txt
#   inflating: dataset1/images/validation/787_person.jpg
#   inflating: dataset1/images/validation/787_person.txt
#   inflating: dataset1/images/validation/788_person.jpg
#   inflating: dataset1/images/validation/788_person.txt
#   inflating: dataset1/images/validation/789_person.jpg
#   inflating: dataset1/images/validation/789_person.txt
#   inflating: dataset1/images/validation/78_person.jpg
#   inflating: dataset1/images/validation/78_person.txt
#   inflating: dataset1/images/validation/790_person.jpg
#   inflating: dataset1/images/validation/790_person.txt
#   inflating: dataset1/images/validation/791_person.jpg
#   inflating: dataset1/images/validation/791_person.txt
#   inflating: dataset1/images/validation/792_person.jpg
#   inflating: dataset1/images/validation/792_person.txt
#   inflating: dataset1/images/validation/793_person.jpg
#   inflating: dataset1/images/validation/793_person.txt
#   inflating: dataset1/images/validation/794_person.jpg
#   inflating: dataset1/images/validation/794_person.txt
#   inflating: dataset1/images/validation/795_person.jpg
#   inflating: dataset1/images/validation/795_person.txt
#   inflating: dataset1/images/validation/796_person.jpg
#   inflating: dataset1/images/validation/796_person.txt
#   inflating: dataset1/images/validation/797_person.jpg
#   inflating: dataset1/images/validation/797_person.txt
#   inflating: dataset1/images/validation/798_person.jpg
#   inflating: dataset1/images/validation/798_person.txt
#   inflating: dataset1/images/validation/799_person.jpg
#   inflating: dataset1/images/validation/799_person.txt
#   inflating: dataset1/images/validation/79_person.jpg
#   inflating: dataset1/images/validation/79_person.txt
#   inflating: dataset1/images/validation/7_person.jpg
#   inflating: dataset1/images/validation/7_person.txt
#   inflating: dataset1/images/validation/800_person.jpg
#   inflating: dataset1/images/validation/800_person.txt
#   inflating: dataset1/images/validation/801_person.jpg
#   inflating: dataset1/images/validation/801_person.txt
#   inflating: dataset1/images/validation/802_person.jpg
#   inflating: dataset1/images/validation/802_person.txt
#   inflating: dataset1/images/validation/803_person.jpg
#   inflating: dataset1/images/validation/804_person.jpg
#   inflating: dataset1/images/validation/804_person.txt
#   inflating: dataset1/images/validation/805_person.jpg
#   inflating: dataset1/images/validation/805_person.txt
#   inflating: dataset1/images/validation/806_person.jpg
#   inflating: dataset1/images/validation/806_person.txt
#   inflating: dataset1/images/validation/807_person.jpg
#   inflating: dataset1/images/validation/807_person.txt
#   inflating: dataset1/images/validation/808_person.jpg
#   inflating: dataset1/images/validation/808_person.txt
#   inflating: dataset1/images/validation/809_person.jpg
#   inflating: dataset1/images/validation/809_person.txt
#   inflating: dataset1/images/validation/80_person.jpg
#   inflating: dataset1/images/validation/80_person.txt
#   inflating: dataset1/images/validation/810_person.jpg
#   inflating: dataset1/images/validation/810_person.txt
#   inflating: dataset1/images/validation/811_person.jpg
#   inflating: dataset1/images/validation/811_person.txt
#   inflating: dataset1/images/validation/812_person.jpg
#   inflating: dataset1/images/validation/812_person.txt
#   inflating: dataset1/images/validation/813_person.jpg
#   inflating: dataset1/images/validation/813_person.txt
#   inflating: dataset1/images/validation/814_person.jpg
#   inflating: dataset1/images/validation/814_person.txt
#   inflating: dataset1/images/validation/815_person.jpg
#   inflating: dataset1/images/validation/815_person.txt
#   inflating: dataset1/images/validation/816_person.jpg
#   inflating: dataset1/images/validation/816_person.txt
#   inflating: dataset1/images/validation/817_person.jpg
#   inflating: dataset1/images/validation/817_person.txt
#   inflating: dataset1/images/validation/818_person.jpg
#   inflating: dataset1/images/validation/818_person.txt
#   inflating: dataset1/images/validation/819_person.jpg
#   inflating: dataset1/images/validation/819_person.txt
#   inflating: dataset1/images/validation/81_person.jpg
#   inflating: dataset1/images/validation/81_person.txt
#   inflating: dataset1/images/validation/820_person.jpg
#   inflating: dataset1/images/validation/820_person.txt
#   inflating: dataset1/images/validation/821_person.jpg
#   inflating: dataset1/images/validation/821_person.txt
#   inflating: dataset1/images/validation/822_person.jpg
#   inflating: dataset1/images/validation/822_person.txt
#   inflating: dataset1/images/validation/823_person.jpg
#   inflating: dataset1/images/validation/823_person.txt
#   inflating: dataset1/images/validation/824_person.jpg
#   inflating: dataset1/images/validation/824_person.txt
#   inflating: dataset1/images/validation/825_person.jpg
#   inflating: dataset1/images/validation/825_person.txt
#   inflating: dataset1/images/validation/826_person.jpg
#   inflating: dataset1/images/validation/826_person.txt
#   inflating: dataset1/images/validation/827_person.jpg
#   inflating: dataset1/images/validation/827_person.txt
#   inflating: dataset1/images/validation/828_person.jpg
#   inflating: dataset1/images/validation/828_person.txt
#   inflating: dataset1/images/validation/829_person.jpg
#   inflating: dataset1/images/validation/829_person.txt
#   inflating: dataset1/images/validation/82_person.jpg
#   inflating: dataset1/images/validation/82_person.txt
#   inflating: dataset1/images/validation/830_person.jpg
#   inflating: dataset1/images/validation/830_person.txt
#   inflating: dataset1/images/validation/831_person.jpg
#   inflating: dataset1/images/validation/831_person.txt
#   inflating: dataset1/images/validation/832_person.jpg
#   inflating: dataset1/images/validation/832_person.txt
#   inflating: dataset1/images/validation/833_person.jpg
#   inflating: dataset1/images/validation/833_person.txt
#   inflating: dataset1/images/validation/834_person.jpg
#   inflating: dataset1/images/validation/834_person.txt
#   inflating: dataset1/images/validation/835_person.jpg
#   inflating: dataset1/images/validation/835_person.txt
#   inflating: dataset1/images/validation/836_person.jpg
#   inflating: dataset1/images/validation/836_person.txt
#   inflating: dataset1/images/validation/837_person.jpg
#   inflating: dataset1/images/validation/837_person.txt
#   inflating: dataset1/images/validation/838_person.jpg
#   inflating: dataset1/images/validation/838_person.txt
#   inflating: dataset1/images/validation/839_person.jpg
#   inflating: dataset1/images/validation/839_person.txt
#   inflating: dataset1/images/validation/83_person.jpg
#   inflating: dataset1/images/validation/83_person.txt
#   inflating: dataset1/images/validation/840_person.jpg
#   inflating: dataset1/images/validation/840_person.txt
#   inflating: dataset1/images/validation/841_person.jpg
#   inflating: dataset1/images/validation/842_person.jpg
#   inflating: dataset1/images/validation/842_person.txt
#   inflating: dataset1/images/validation/843_person.jpg
#   inflating: dataset1/images/validation/843_person.txt
#   inflating: dataset1/images/validation/844_person.jpg
#   inflating: dataset1/images/validation/844_person.txt
#   inflating: dataset1/images/validation/845_person.jpg
#   inflating: dataset1/images/validation/845_person.txt
#   inflating: dataset1/images/validation/846_person.jpg
#   inflating: dataset1/images/validation/846_person.txt
#   inflating: dataset1/images/validation/847_person.jpg
#   inflating: dataset1/images/validation/847_person.txt
#   inflating: dataset1/images/validation/848_person.jpg
#   inflating: dataset1/images/validation/848_person.txt
#   inflating: dataset1/images/validation/849_person.jpg
#   inflating: dataset1/images/validation/849_person.txt
#   inflating: dataset1/images/validation/84_person.jpg
#   inflating: dataset1/images/validation/850_person.jpg
#   inflating: dataset1/images/validation/850_person.txt
#   inflating: dataset1/images/validation/851_person.jpg
#   inflating: dataset1/images/validation/852_person.jpg
#   inflating: dataset1/images/validation/852_person.txt
#   inflating: dataset1/images/validation/853_person.jpg
#   inflating: dataset1/images/validation/853_person.txt
#   inflating: dataset1/images/validation/854_person.jpg
#   inflating: dataset1/images/validation/854_person.txt
#   inflating: dataset1/images/validation/85_person.jpg
#   inflating: dataset1/images/validation/85_person.txt
#   inflating: dataset1/images/validation/86_person.jpg
#   inflating: dataset1/images/validation/86_person.txt
#   inflating: dataset1/images/validation/87_person.jpg
#   inflating: dataset1/images/validation/87_person.txt
#   inflating: dataset1/images/validation/88_person.jpg
#   inflating: dataset1/images/validation/88_person.txt
#   inflating: dataset1/images/validation/89_person.jpg
#   inflating: dataset1/images/validation/89_person.txt
#   inflating: dataset1/images/validation/8_person.jpg
#   inflating: dataset1/images/validation/8_person.txt
#   inflating: dataset1/images/validation/90_person.jpg
#   inflating: dataset1/images/validation/90_person.txt
#   inflating: dataset1/images/validation/91_person.jpg
#   inflating: dataset1/images/validation/91_person.txt
#   inflating: dataset1/images/validation/92_person.jpg
#   inflating: dataset1/images/validation/92_person.txt
#   inflating: dataset1/images/validation/93_person.jpg
#   inflating: dataset1/images/validation/93_person.txt
#   inflating: dataset1/images/validation/94_person.jpg
#   inflating: dataset1/images/validation/94_person.txt
#   inflating: dataset1/images/validation/95_person.jpg
#   inflating: dataset1/images/validation/95_person.txt
#   inflating: dataset1/images/validation/96_person.jpg
#   inflating: dataset1/images/validation/96_person.txt
#   inflating: dataset1/images/validation/97_person.jpg
#   inflating: dataset1/images/validation/97_person.txt
#   inflating: dataset1/images/validation/98_person.jpg
#   inflating: dataset1/images/validation/98_person.txt
#   inflating: dataset1/images/validation/99_person.jpg
#   inflating: dataset1/images/validation/99_person.txt
#   inflating: dataset1/images/validation/9_person.jpg
#   inflating: dataset1/images/validation/9_person.txt
#   inflating: dataset1/images/validation/classes.txt
#   inflating: dataset1/images/validation/person_ (1).jpg
#   inflating: dataset1/images/validation/person_ (1).txt
#   inflating: dataset1/images/validation/person_ (10).jpg
#   inflating: dataset1/images/validation/person_ (10).txt
#   inflating: dataset1/images/validation/person_ (100).jpg
#   inflating: dataset1/images/validation/person_ (100).txt
#   inflating: dataset1/images/validation/person_ (101).jpg
#   inflating: dataset1/images/validation/person_ (101).txt
#   inflating: dataset1/images/validation/person_ (102).jpg
#   inflating: dataset1/images/validation/person_ (102).txt
#   inflating: dataset1/images/validation/person_ (103).jpg
#   inflating: dataset1/images/validation/person_ (103).txt
#   inflating: dataset1/images/validation/person_ (104).jpg
#   inflating: dataset1/images/validation/person_ (104).txt
#   inflating: dataset1/images/validation/person_ (105).jpg
#   inflating: dataset1/images/validation/person_ (105).txt
#   inflating: dataset1/images/validation/person_ (106).jpg
#   inflating: dataset1/images/validation/person_ (106).txt
#   inflating: dataset1/images/validation/person_ (107).jpg
#   inflating: dataset1/images/validation/person_ (107).txt
#   inflating: dataset1/images/validation/person_ (108).jpg
#   inflating: dataset1/images/validation/person_ (108).txt
#   inflating: dataset1/images/validation/person_ (109).jpg
#   inflating: dataset1/images/validation/person_ (109).txt
#   inflating: dataset1/images/validation/person_ (11).jpg
#   inflating: dataset1/images/validation/person_ (11).txt
#   inflating: dataset1/images/validation/person_ (110).jpg
#   inflating: dataset1/images/validation/person_ (110).txt
#   inflating: dataset1/images/validation/person_ (111).jpg
#   inflating: dataset1/images/validation/person_ (111).txt
#   inflating: dataset1/images/validation/person_ (112).jpg
#   inflating: dataset1/images/validation/person_ (112).txt
#   inflating: dataset1/images/validation/person_ (113).jpg
#   inflating: dataset1/images/validation/person_ (113).txt
#   inflating: dataset1/images/validation/person_ (114).jpg
#   inflating: dataset1/images/validation/person_ (114).txt
#   inflating: dataset1/images/validation/person_ (115).jpg
#   inflating: dataset1/images/validation/person_ (115).txt
#   inflating: dataset1/images/validation/person_ (116).jpg
#   inflating: dataset1/images/validation/person_ (116).txt
#   inflating: dataset1/images/validation/person_ (117).jpg
#   inflating: dataset1/images/validation/person_ (117).txt
#   inflating: dataset1/images/validation/person_ (118).jpg
#   inflating: dataset1/images/validation/person_ (118).txt
#   inflating: dataset1/images/validation/person_ (119).jpg
#   inflating: dataset1/images/validation/person_ (119).txt
#   inflating: dataset1/images/validation/person_ (12).jpg
#   inflating: dataset1/images/validation/person_ (12).txt
#   inflating: dataset1/images/validation/person_ (120).jpg
#   inflating: dataset1/images/validation/person_ (120).txt
#   inflating: dataset1/images/validation/person_ (121).jpg
#   inflating: dataset1/images/validation/person_ (121).txt
#   inflating: dataset1/images/validation/person_ (122).jpg
#   inflating: dataset1/images/validation/person_ (122).txt
#   inflating: dataset1/images/validation/person_ (123).jpg
#   inflating: dataset1/images/validation/person_ (123).txt
#   inflating: dataset1/images/validation/person_ (124).jpg
#   inflating: dataset1/images/validation/person_ (124).txt
#   inflating: dataset1/images/validation/person_ (125).jpg
#   inflating: dataset1/images/validation/person_ (125).txt
#   inflating: dataset1/images/validation/person_ (126).jpg
#   inflating: dataset1/images/validation/person_ (126).txt
#   inflating: dataset1/images/validation/person_ (127).jpg
#   inflating: dataset1/images/validation/person_ (127).txt
#   inflating: dataset1/images/validation/person_ (128).jpg
#   inflating: dataset1/images/validation/person_ (128).txt
#   inflating: dataset1/images/validation/person_ (129).jpg
#   inflating: dataset1/images/validation/person_ (129).txt
#   inflating: dataset1/images/validation/person_ (13).jpg
#   inflating: dataset1/images/validation/person_ (13).txt
#   inflating: dataset1/images/validation/person_ (130).jpg
#   inflating: dataset1/images/validation/person_ (130).txt
#   inflating: dataset1/images/validation/person_ (131).jpg
#   inflating: dataset1/images/validation/person_ (131).txt
#   inflating: dataset1/images/validation/person_ (132).jpg
#   inflating: dataset1/images/validation/person_ (132).txt
#   inflating: dataset1/images/validation/person_ (133).jpg
#   inflating: dataset1/images/validation/person_ (133).txt
#   inflating: dataset1/images/validation/person_ (134).jpg
#   inflating: dataset1/images/validation/person_ (134).txt
#   inflating: dataset1/images/validation/person_ (135).jpg
#   inflating: dataset1/images/validation/person_ (135).txt
#   inflating: dataset1/images/validation/person_ (136).jpg
#   inflating: dataset1/images/validation/person_ (136).txt
#   inflating: dataset1/images/validation/person_ (137).jpg
#   inflating: dataset1/images/validation/person_ (137).txt
#   inflating: dataset1/images/validation/person_ (138).jpg
#   inflating: dataset1/images/validation/person_ (138).txt
#   inflating: dataset1/images/validation/person_ (139).jpg
#   inflating: dataset1/images/validation/person_ (139).txt
#   inflating: dataset1/images/validation/person_ (14).jpg
#   inflating: dataset1/images/validation/person_ (14).txt
#   inflating: dataset1/images/validation/person_ (140).jpg
#   inflating: dataset1/images/validation/person_ (140).txt
#   inflating: dataset1/images/validation/person_ (141).jpg
#   inflating: dataset1/images/validation/person_ (141).txt
#   inflating: dataset1/images/validation/person_ (142).jpg
#   inflating: dataset1/images/validation/person_ (142).txt
#   inflating: dataset1/images/validation/person_ (143).jpg
#   inflating: dataset1/images/validation/person_ (143).txt
#   inflating: dataset1/images/validation/person_ (144).jpg
#   inflating: dataset1/images/validation/person_ (144).txt
#   inflating: dataset1/images/validation/person_ (145).jpg
#   inflating: dataset1/images/validation/person_ (145).txt
#   inflating: dataset1/images/validation/person_ (146).jpg
#   inflating: dataset1/images/validation/person_ (146).txt
#   inflating: dataset1/images/validation/person_ (147).jpg
#   inflating: dataset1/images/validation/person_ (147).txt
#   inflating: dataset1/images/validation/person_ (148).jpg
#   inflating: dataset1/images/validation/person_ (148).txt
#   inflating: dataset1/images/validation/person_ (149).jpg
#   inflating: dataset1/images/validation/person_ (149).txt
#   inflating: dataset1/images/validation/person_ (15).jpg
#   inflating: dataset1/images/validation/person_ (15).txt
#   inflating: dataset1/images/validation/person_ (150).jpg
#   inflating: dataset1/images/validation/person_ (150).txt
#   inflating: dataset1/images/validation/person_ (151).jpg
#   inflating: dataset1/images/validation/person_ (151).txt
#   inflating: dataset1/images/validation/person_ (152).jpg
#   inflating: dataset1/images/validation/person_ (152).txt
#   inflating: dataset1/images/validation/person_ (153).jpg
#   inflating: dataset1/images/validation/person_ (153).txt
#   inflating: dataset1/images/validation/person_ (154).jpg
#   inflating: dataset1/images/validation/person_ (154).txt
#   inflating: dataset1/images/validation/person_ (155).jpg
#   inflating: dataset1/images/validation/person_ (155).txt
#   inflating: dataset1/images/validation/person_ (156).jpg
#   inflating: dataset1/images/validation/person_ (156).txt
#   inflating: dataset1/images/validation/person_ (157).jpg
#   inflating: dataset1/images/validation/person_ (157).txt
#   inflating: dataset1/images/validation/person_ (158).jpg
#   inflating: dataset1/images/validation/person_ (158).txt
#   inflating: dataset1/images/validation/person_ (159).jpg
#   inflating: dataset1/images/validation/person_ (159).txt
#   inflating: dataset1/images/validation/person_ (16).jpg
#   inflating: dataset1/images/validation/person_ (16).txt
#   inflating: dataset1/images/validation/person_ (160).jpg
#   inflating: dataset1/images/validation/person_ (160).txt
#   inflating: dataset1/images/validation/person_ (161).jpg
#   inflating: dataset1/images/validation/person_ (161).txt
#   inflating: dataset1/images/validation/person_ (162).jpg
#   inflating: dataset1/images/validation/person_ (162).txt
#   inflating: dataset1/images/validation/person_ (163).jpg
#   inflating: dataset1/images/validation/person_ (163).txt
#   inflating: dataset1/images/validation/person_ (164).jpg
#   inflating: dataset1/images/validation/person_ (164).txt
#   inflating: dataset1/images/validation/person_ (165).jpg
#   inflating: dataset1/images/validation/person_ (165).txt
#   inflating: dataset1/images/validation/person_ (166).jpg
#   inflating: dataset1/images/validation/person_ (166).txt
#   inflating: dataset1/images/validation/person_ (167).jpg
#   inflating: dataset1/images/validation/person_ (167).txt
#   inflating: dataset1/images/validation/person_ (168).jpg
#   inflating: dataset1/images/validation/person_ (168).txt
#   inflating: dataset1/images/validation/person_ (169).jpg
#   inflating: dataset1/images/validation/person_ (169).txt
#   inflating: dataset1/images/validation/person_ (17).jpg
#   inflating: dataset1/images/validation/person_ (17).txt
#   inflating: dataset1/images/validation/person_ (170).jpg
#   inflating: dataset1/images/validation/person_ (170).txt
#   inflating: dataset1/images/validation/person_ (171).jpg
#   inflating: dataset1/images/validation/person_ (171).txt
#   inflating: dataset1/images/validation/person_ (172).jpg
#   inflating: dataset1/images/validation/person_ (172).txt
#   inflating: dataset1/images/validation/person_ (173).jpg
#   inflating: dataset1/images/validation/person_ (173).txt
#   inflating: dataset1/images/validation/person_ (174).jpg
#   inflating: dataset1/images/validation/person_ (174).txt
#   inflating: dataset1/images/validation/person_ (175).jpg
#   inflating: dataset1/images/validation/person_ (175).txt
#   inflating: dataset1/images/validation/person_ (176).jpg
#   inflating: dataset1/images/validation/person_ (176).txt
#   inflating: dataset1/images/validation/person_ (177).jpg
#   inflating: dataset1/images/validation/person_ (177).txt
#   inflating: dataset1/images/validation/person_ (178).jpg
#   inflating: dataset1/images/validation/person_ (178).txt
#   inflating: dataset1/images/validation/person_ (179).jpg
#   inflating: dataset1/images/validation/person_ (179).txt
#   inflating: dataset1/images/validation/person_ (18).jpg
#   inflating: dataset1/images/validation/person_ (18).txt
#   inflating: dataset1/images/validation/person_ (180).jpg
#   inflating: dataset1/images/validation/person_ (180).txt
#   inflating: dataset1/images/validation/person_ (181).jpg
#   inflating: dataset1/images/validation/person_ (181).txt
#   inflating: dataset1/images/validation/person_ (182).jpg
#   inflating: dataset1/images/validation/person_ (182).txt
#   inflating: dataset1/images/validation/person_ (19).jpg
#   inflating: dataset1/images/validation/person_ (19).txt
#   inflating: dataset1/images/validation/person_ (2).jpg
#   inflating: dataset1/images/validation/person_ (2).txt
#   inflating: dataset1/images/validation/person_ (20).jpg
#   inflating: dataset1/images/validation/person_ (20).txt
#   inflating: dataset1/images/validation/person_ (21).jpg
#   inflating: dataset1/images/validation/person_ (21).txt
#   inflating: dataset1/images/validation/person_ (22).jpg
#   inflating: dataset1/images/validation/person_ (22).txt
#   inflating: dataset1/images/validation/person_ (23).jpg
#   inflating: dataset1/images/validation/person_ (23).txt
#   inflating: dataset1/images/validation/person_ (24).jpg
#   inflating: dataset1/images/validation/person_ (24).txt
#   inflating: dataset1/images/validation/person_ (25).jpg
#   inflating: dataset1/images/validation/person_ (25).txt
#   inflating: dataset1/images/validation/person_ (26).jpg
#   inflating: dataset1/images/validation/person_ (26).txt
#   inflating: dataset1/images/validation/person_ (27).jpg
#   inflating: dataset1/images/validation/person_ (27).txt
#   inflating: dataset1/images/validation/person_ (28).jpg
#   inflating: dataset1/images/validation/person_ (28).txt
#   inflating: dataset1/images/validation/person_ (29).jpg
#   inflating: dataset1/images/validation/person_ (29).txt
#   inflating: dataset1/images/validation/person_ (3).jpg
#   inflating: dataset1/images/validation/person_ (3).txt
#   inflating: dataset1/images/validation/person_ (30).jpg
#   inflating: dataset1/images/validation/person_ (30).txt
#   inflating: dataset1/images/validation/person_ (31).jpg
#   inflating: dataset1/images/validation/person_ (31).txt
#   inflating: dataset1/images/validation/person_ (32).jpg
#   inflating: dataset1/images/validation/person_ (32).txt
#   inflating: dataset1/images/validation/person_ (33).jpg
#   inflating: dataset1/images/validation/person_ (33).txt
#   inflating: dataset1/images/validation/person_ (34).jpg
#   inflating: dataset1/images/validation/person_ (34).txt
#   inflating: dataset1/images/validation/person_ (35).jpg
#   inflating: dataset1/images/validation/person_ (35).txt
#   inflating: dataset1/images/validation/person_ (36).jpg
#   inflating: dataset1/images/validation/person_ (36).txt
#   inflating: dataset1/images/validation/person_ (37).jpg
#   inflating: dataset1/images/validation/person_ (37).txt
#   inflating: dataset1/images/validation/person_ (38).jpg
#   inflating: dataset1/images/validation/person_ (38).txt
#   inflating: dataset1/images/validation/person_ (39).jpg
#   inflating: dataset1/images/validation/person_ (39).txt
#   inflating: dataset1/images/validation/person_ (4).jpg
#   inflating: dataset1/images/validation/person_ (4).txt
#   inflating: dataset1/images/validation/person_ (40).jpg
#   inflating: dataset1/images/validation/person_ (40).txt
#   inflating: dataset1/images/validation/person_ (41).jpg
#   inflating: dataset1/images/validation/person_ (41).txt
#   inflating: dataset1/images/validation/person_ (42).jpg
#   inflating: dataset1/images/validation/person_ (42).txt
#   inflating: dataset1/images/validation/person_ (43).jpg
#   inflating: dataset1/images/validation/person_ (43).txt
#   inflating: dataset1/images/validation/person_ (44).jpg
#   inflating: dataset1/images/validation/person_ (44).txt
#   inflating: dataset1/images/validation/person_ (45).jpg
#   inflating: dataset1/images/validation/person_ (45).txt
#   inflating: dataset1/images/validation/person_ (46).jpg
#   inflating: dataset1/images/validation/person_ (46).txt
# ...
#   inflating: dataset1/labels/validation/person_ (141).jpg
#   inflating: dataset1/labels/validation/person_ (141).txt
#   inflating: dataset1/labels/validation/person_ (142).jpg
#   inflating: dataset1/labels/validation/person_ (142).txt
#   inflating: dataset1/labels/validation/person_ (143).jpg
#   inflating: dataset1/labels/validation/person_ (143).txt
#   inflating: dataset1/labels/validation/person_ (144).jpg
#   inflating: dataset1/labels/validation/person_ (144).txt
#   inflating: dataset1/labels/validation/person_ (145).jpg
#   inflating: dataset1/labels/validation/person_ (145).txt
#   inflating: dataset1/labels/validation/person_ (146).jpg
#   inflating: dataset1/labels/validation/person_ (146).txt
#   inflating: dataset1/labels/validation/person_ (147).jpg
#   inflating: dataset1/labels/validation/person_ (147).txt
#   inflating: dataset1/labels/validation/person_ (148).jpg
#   inflating: dataset1/labels/validation/person_ (148).txt
#   inflating: dataset1/labels/validation/person_ (149).jpg
#   inflating: dataset1/labels/validation/person_ (149).txt
#   inflating: dataset1/labels/validation/person_ (15).jpg
#   inflating: dataset1/labels/validation/person_ (15).txt
#   inflating: dataset1/labels/validation/person_ (150).jpg
#   inflating: dataset1/labels/validation/person_ (150).txt
#   inflating: dataset1/labels/validation/person_ (151).jpg
#   inflating: dataset1/labels/validation/person_ (151).txt
#   inflating: dataset1/labels/validation/person_ (152).jpg
#   inflating: dataset1/labels/validation/person_ (152).txt
#   inflating: dataset1/labels/validation/person_ (153).jpg
#   inflating: dataset1/labels/validation/person_ (153).txt
#   inflating: dataset1/labels/validation/person_ (154).jpg
#   inflating: dataset1/labels/validation/person_ (154).txt
#   inflating: dataset1/labels/validation/person_ (155).jpg
#   inflating: dataset1/labels/validation/person_ (155).txt
#   inflating: dataset1/labels/validation/person_ (156).jpg
#   inflating: dataset1/labels/validation/person_ (156).txt
#   inflating: dataset1/labels/validation/person_ (157).jpg
#   inflating: dataset1/labels/validation/person_ (157).txt
#   inflating: dataset1/labels/validation/person_ (158).jpg
#   inflating: dataset1/labels/validation/person_ (158).txt
#   inflating: dataset1/labels/validation/person_ (159).jpg
#   inflating: dataset1/labels/validation/person_ (159).txt
#   inflating: dataset1/labels/validation/person_ (16).jpg
#   inflating: dataset1/labels/validation/person_ (16).txt
#   inflating: dataset1/labels/validation/person_ (160).jpg
#   inflating: dataset1/labels/validation/person_ (160).txt
#   inflating: dataset1/labels/validation/person_ (161).jpg
#   inflating: dataset1/labels/validation/person_ (161).txt
#   inflating: dataset1/labels/validation/person_ (162).jpg
#   inflating: dataset1/labels/validation/person_ (162).txt
#   inflating: dataset1/labels/validation/person_ (163).jpg
#   inflating: dataset1/labels/validation/person_ (163).txt
#   inflating: dataset1/labels/validation/person_ (164).jpg
#   inflating: dataset1/labels/validation/person_ (164).txt
#   inflating: dataset1/labels/validation/person_ (165).jpg
#   inflating: dataset1/labels/validation/person_ (165).txt
#   inflating: dataset1/labels/validation/person_ (166).jpg
#   inflating: dataset1/labels/validation/person_ (166).txt
#   inflating: dataset1/labels/validation/person_ (167).jpg
#   inflating: dataset1/labels/validation/person_ (167).txt
#   inflating: dataset1/labels/validation/person_ (168).jpg
#   inflating: dataset1/labels/validation/person_ (168).txt
#   inflating: dataset1/labels/validation/person_ (169).jpg
#   inflating: dataset1/labels/validation/person_ (169).txt
#   inflating: dataset1/labels/validation/person_ (17).jpg
#   inflating: dataset1/labels/validation/person_ (17).txt
#   inflating: dataset1/labels/validation/person_ (170).jpg
#   inflating: dataset1/labels/validation/person_ (170).txt
#   inflating: dataset1/labels/validation/person_ (171).jpg
#   inflating: dataset1/labels/validation/person_ (171).txt
#   inflating: dataset1/labels/validation/person_ (172).jpg
#   inflating: dataset1/labels/validation/person_ (172).txt
#   inflating: dataset1/labels/validation/person_ (173).jpg
#   inflating: dataset1/labels/validation/person_ (173).txt
#   inflating: dataset1/labels/validation/person_ (174).jpg
#   inflating: dataset1/labels/validation/person_ (174).txt
#   inflating: dataset1/labels/validation/person_ (175).jpg
#   inflating: dataset1/labels/validation/person_ (175).txt
#   inflating: dataset1/labels/validation/person_ (176).jpg
#   inflating: dataset1/labels/validation/person_ (176).txt
#   inflating: dataset1/labels/validation/person_ (177).jpg
#   inflating: dataset1/labels/validation/person_ (177).txt
#   inflating: dataset1/labels/validation/person_ (178).jpg
#   inflating: dataset1/labels/validation/person_ (178).txt
#   inflating: dataset1/labels/validation/person_ (179).jpg
#   inflating: dataset1/labels/validation/person_ (179).txt
#   inflating: dataset1/labels/validation/person_ (18).jpg
#   inflating: dataset1/labels/validation/person_ (18).txt
#   inflating: dataset1/labels/validation/person_ (180).jpg
#   inflating: dataset1/labels/validation/person_ (180).txt
#   inflating: dataset1/labels/validation/person_ (181).jpg
#   inflating: dataset1/labels/validation/person_ (181).txt
#   inflating: dataset1/labels/validation/person_ (182).jpg
#   inflating: dataset1/labels/validation/person_ (182).txt
#   inflating: dataset1/labels/validation/person_ (19).jpg
#   inflating: dataset1/labels/validation/person_ (19).txt
#   inflating: dataset1/labels/validation/person_ (2).jpg
#   inflating: dataset1/labels/validation/person_ (2).txt
#   inflating: dataset1/labels/validation/person_ (20).jpg
#   inflating: dataset1/labels/validation/person_ (20).txt
#   inflating: dataset1/labels/validation/person_ (21).jpg
#   inflating: dataset1/labels/validation/person_ (21).txt
#   inflating: dataset1/labels/validation/person_ (22).jpg
#   inflating: dataset1/labels/validation/person_ (22).txt
#   inflating: dataset1/labels/validation/person_ (23).jpg
#   inflating: dataset1/labels/validation/person_ (23).txt
#   inflating: dataset1/labels/validation/person_ (24).jpg
#   inflating: dataset1/labels/validation/person_ (24).txt
#   inflating: dataset1/labels/validation/person_ (25).jpg
#   inflating: dataset1/labels/validation/person_ (25).txt
#   inflating: dataset1/labels/validation/person_ (26).jpg
#   inflating: dataset1/labels/validation/person_ (26).txt
#   inflating: dataset1/labels/validation/person_ (27).jpg
#   inflating: dataset1/labels/validation/person_ (27).txt
#   inflating: dataset1/labels/validation/person_ (28).jpg
#   inflating: dataset1/labels/validation/person_ (28).txt
#   inflating: dataset1/labels/validation/person_ (29).jpg
#   inflating: dataset1/labels/validation/person_ (29).txt
#   inflating: dataset1/labels/validation/person_ (3).jpg
#   inflating: dataset1/labels/validation/person_ (3).txt
#   inflating: dataset1/labels/validation/person_ (30).jpg
#   inflating: dataset1/labels/validation/person_ (30).txt
#   inflating: dataset1/labels/validation/person_ (31).jpg
#   inflating: dataset1/labels/validation/person_ (31).txt
#   inflating: dataset1/labels/validation/person_ (32).jpg
#   inflating: dataset1/labels/validation/person_ (32).txt
#   inflating: dataset1/labels/validation/person_ (33).jpg
#   inflating: dataset1/labels/validation/person_ (33).txt
#   inflating: dataset1/labels/validation/person_ (34).jpg
#   inflating: dataset1/labels/validation/person_ (34).txt
#   inflating: dataset1/labels/validation/person_ (35).jpg
#   inflating: dataset1/labels/validation/person_ (35).txt
#   inflating: dataset1/labels/validation/person_ (36).jpg
#   inflating: dataset1/labels/validation/person_ (36).txt
#   inflating: dataset1/labels/validation/person_ (37).jpg
#   inflating: dataset1/labels/validation/person_ (37).txt
#   inflating: dataset1/labels/validation/person_ (38).jpg
#   inflating: dataset1/labels/validation/person_ (38).txt
#   inflating: dataset1/labels/validation/person_ (39).jpg
#   inflating: dataset1/labels/validation/person_ (39).txt
#   inflating: dataset1/labels/validation/person_ (4).jpg
#   inflating: dataset1/labels/validation/person_ (4).txt
#   inflating: dataset1/labels/validation/person_ (40).jpg
#   inflating: dataset1/labels/validation/person_ (40).txt
#   inflating: dataset1/labels/validation/person_ (41).jpg
#   inflating: dataset1/labels/validation/person_ (41).txt
#   inflating: dataset1/labels/validation/person_ (42).jpg
#   inflating: dataset1/labels/validation/person_ (42).txt
#   inflating: dataset1/labels/validation/person_ (43).jpg
#   inflating: dataset1/labels/validation/person_ (43).txt
#   inflating: dataset1/labels/validation/person_ (44).jpg
#   inflating: dataset1/labels/validation/person_ (44).txt
#   inflating: dataset1/labels/validation/person_ (45).jpg
#   inflating: dataset1/labels/validation/person_ (45).txt
#   inflating: dataset1/labels/validation/person_ (46).jpg
#   inflating: dataset1/labels/validation/person_ (46).txt
#   inflating: dataset1/labels/validation/person_ (47).jpg
#   inflating: dataset1/labels/validation/person_ (47).txt
#   inflating: dataset1/labels/validation/person_ (48).jpg
#   inflating: dataset1/labels/validation/person_ (48).txt
#   inflating: dataset1/labels/validation/person_ (49).jpg
#   inflating: dataset1/labels/validation/person_ (49).txt
#   inflating: dataset1/labels/validation/person_ (5).jpg
#   inflating: dataset1/labels/validation/person_ (5).txt
#   inflating: dataset1/labels/validation/person_ (50).jpg
#   inflating: dataset1/labels/validation/person_ (50).txt
#   inflating: dataset1/labels/validation/person_ (51).jpg
#   inflating: dataset1/labels/validation/person_ (51).txt
#   inflating: dataset1/labels/validation/person_ (52).jpg
#   inflating: dataset1/labels/validation/person_ (52).txt
#   inflating: dataset1/labels/validation/person_ (53).jpg
#   inflating: dataset1/labels/validation/person_ (53).txt
#   inflating: dataset1/labels/validation/person_ (54).jpg
#   inflating: dataset1/labels/validation/person_ (54).txt
#   inflating: dataset1/labels/validation/person_ (55).jpg
#   inflating: dataset1/labels/validation/person_ (55).txt
#   inflating: dataset1/labels/validation/person_ (56).jpg
#   inflating: dataset1/labels/validation/person_ (56).txt
#   inflating: dataset1/labels/validation/person_ (57).jpg
#   inflating: dataset1/labels/validation/person_ (57).txt
#   inflating: dataset1/labels/validation/person_ (58).jpg
#   inflating: dataset1/labels/validation/person_ (58).txt
#   inflating: dataset1/labels/validation/person_ (59).jpg
#   inflating: dataset1/labels/validation/person_ (59).txt
#   inflating: dataset1/labels/validation/person_ (6).jpg
#   inflating: dataset1/labels/validation/person_ (6).txt
#   inflating: dataset1/labels/validation/person_ (60).jpg
#   inflating: dataset1/labels/validation/person_ (60).txt
#   inflating: dataset1/labels/validation/person_ (61).jpg
#   inflating: dataset1/labels/validation/person_ (61).txt
#   inflating: dataset1/labels/validation/person_ (62).jpg
#   inflating: dataset1/labels/validation/person_ (62).txt
#   inflating: dataset1/labels/validation/person_ (63).jpg
#   inflating: dataset1/labels/validation/person_ (63).txt
#   inflating: dataset1/labels/validation/person_ (64).jpg
#   inflating: dataset1/labels/validation/person_ (64).txt
#   inflating: dataset1/labels/validation/person_ (65).jpg
#   inflating: dataset1/labels/validation/person_ (65).txt
#   inflating: dataset1/labels/validation/person_ (66).jpg
#   inflating: dataset1/labels/validation/person_ (66).txt
#   inflating: dataset1/labels/validation/person_ (67).jpg
#   inflating: dataset1/labels/validation/person_ (67).txt
#   inflating: dataset1/labels/validation/person_ (68).jpg
#   inflating: dataset1/labels/validation/person_ (68).txt
#   inflating: dataset1/labels/validation/person_ (69).jpg
#   inflating: dataset1/labels/validation/person_ (69).txt
#   inflating: dataset1/labels/validation/person_ (7).jpg
#   inflating: dataset1/labels/validation/person_ (7).txt
#   inflating: dataset1/labels/validation/person_ (70).jpg
#   inflating: dataset1/labels/validation/person_ (70).txt
#   inflating: dataset1/labels/validation/person_ (71).jpg
#   inflating: dataset1/labels/validation/person_ (71).txt
#   inflating: dataset1/labels/validation/person_ (72).jpg
#   inflating: dataset1/labels/validation/person_ (72).txt
#   inflating: dataset1/labels/validation/person_ (73).jpg
#   inflating: dataset1/labels/validation/person_ (73).txt
#   inflating: dataset1/labels/validation/person_ (74).jpg
#   inflating: dataset1/labels/validation/person_ (74).txt
#   inflating: dataset1/labels/validation/person_ (75).jpg
#   inflating: dataset1/labels/validation/person_ (75).txt
#   inflating: dataset1/labels/validation/person_ (76).jpg
#   inflating: dataset1/labels/validation/person_ (76).txt
#   inflating: dataset1/labels/validation/person_ (77).jpg
#   inflating: dataset1/labels/validation/person_ (77).txt
#   inflating: dataset1/labels/validation/person_ (78).jpg
#   inflating: dataset1/labels/validation/person_ (78).txt
#   inflating: dataset1/labels/validation/person_ (79).jpg
#   inflating: dataset1/labels/validation/person_ (79).txt
#   inflating: dataset1/labels/validation/person_ (8).jpg
#   inflating: dataset1/labels/validation/person_ (8).txt
#   inflating: dataset1/labels/validation/person_ (80).jpg
#   inflating: dataset1/labels/validation/person_ (80).txt
#   inflating: dataset1/labels/validation/person_ (81).jpg
#   inflating: dataset1/labels/validation/person_ (81).txt
#   inflating: dataset1/labels/validation/person_ (82).jpg
#   inflating: dataset1/labels/validation/person_ (82).txt
#   inflating: dataset1/labels/validation/person_ (83).jpg
#   inflating: dataset1/labels/validation/person_ (83).txt
#   inflating: dataset1/labels/validation/person_ (84).jpg
#   inflating: dataset1/labels/validation/person_ (84).txt
#   inflating: dataset1/labels/validation/person_ (85).jpg
#   inflating: dataset1/labels/validation/person_ (85).txt
#   inflating: dataset1/labels/validation/person_ (86).jpg
#   inflating: dataset1/labels/validation/person_ (86).txt
#   inflating: dataset1/labels/validation/person_ (87).jpg
#   inflating: dataset1/labels/validation/person_ (87).txt
#   inflating: dataset1/labels/validation/person_ (88).jpg
#   inflating: dataset1/labels/validation/person_ (88).txt
#   inflating: dataset1/labels/validation/person_ (89).jpg
#   inflating: dataset1/labels/validation/person_ (89).txt
#   inflating: dataset1/labels/validation/person_ (9).jpg
#   inflating: dataset1/labels/validation/person_ (9).txt
#   inflating: dataset1/labels/validation/person_ (90).jpg
#   inflating: dataset1/labels/validation/person_ (90).txt
#   inflating: dataset1/labels/validation/person_ (91).jpg
#   inflating: dataset1/labels/validation/person_ (91).txt
#   inflating: dataset1/labels/validation/person_ (92).jpg
#   inflating: dataset1/labels/validation/person_ (92).txt
#   inflating: dataset1/labels/validation/person_ (93).jpg
#   inflating: dataset1/labels/validation/person_ (93).txt
#   inflating: dataset1/labels/validation/person_ (94).jpg
#   inflating: dataset1/labels/validation/person_ (94).txt
#   inflating: dataset1/labels/validation/person_ (95).jpg
#   inflating: dataset1/labels/validation/person_ (95).txt
#   inflating: dataset1/labels/validation/person_ (96).jpg
#   inflating: dataset1/labels/validation/person_ (96).txt
#   inflating: dataset1/labels/validation/person_ (97).jpg
#   inflating: dataset1/labels/validation/person_ (97).txt
#   inflating: dataset1/labels/validation/person_ (98).jpg
#   inflating: dataset1/labels/validation/person_ (98).txt
#   inflating: dataset1/labels/validation/person_ (99).jpg
#   inflating: dataset1/labels/validation/person_ (99).txt

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data=/content/datasets/dataset/data.yaml epochs=100 imgsz=800 plots=True
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8s.pt to yolov8s.pt...
# 100% 21.5M/21.5M [00:00<00:00, 101MB/s]
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py:332: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(file, map_location='cpu')  # load
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# yolo/engine/trainer: task=detect, mode=train, model=yolov8s.yaml, data=/content/datasets/dataset/data.yaml, epochs=100, patience=50, batch=16, imgsz=800, save=True, cache=False, device=, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=False, val=True, save_json=False, save_hybrid=False, conf=0.001, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=ultralytics/assets/, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.001, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, save_dir=runs/detect/train
# /usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/trainer.py:114: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = amp.GradScaler(enabled=self.amp)
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 40.3MB/s]
# 2024-10-16 09:28:14.562265: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-16 09:28:14.581068: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-16 09:28:14.586983: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-16 09:28:14.601351: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-16 09:28:15.761500: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.Conv                  [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.C2f                   [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.C2f                   [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.Conv                  [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.C2f                   [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.SPPF                  [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    591360  ultralytics.nn.modules.C2f                   [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.Conv                  [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.C2f                   [768, 512, 1]
#  22        [15, 18, 21]  1   2116822  ultralytics.nn.modules.Detect                [2, [128, 256, 512]]
# Model summary: 225 layers, 11136374 parameters, 11136358 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.001), 63 bias
# train: Scanning /content/datasets/dataset/labels/training... 987 images, 50 backgrounds, 0 corrupt: 100% 1037/1037 [00:00<00:00, 1177.81it/s]
# train: New cache created: /content/datasets/dataset/labels/training.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/datasets/dataset/labels/validation... 987 images, 50 backgrounds, 0 corrupt: 100% 1037/1037 [00:00<00:00, 1251.19it/s]
# val: New cache created: /content/datasets/dataset/labels/validation.cache
# Image sizes 800 train, 800 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0% 0/65 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/trainer.py:299: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [32,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [33,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [34,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [35,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [36,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [37,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [38,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [39,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [40,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [41,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [42,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [43,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [44,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [45,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [46,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [47,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [48,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [49,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [50,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [51,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [52,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [53,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [54,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [55,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [56,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [57,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [58,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [59,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [60,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [61,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [62,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [63,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [64,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [65,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [66,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [67,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [68,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [69,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [70,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [71,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [72,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [73,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [74,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [75,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [76,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [77,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [78,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [79,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [80,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [81,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [82,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [83,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [84,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [85,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [86,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [87,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [88,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [89,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [90,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [91,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [92,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [93,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [94,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [95,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [64,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [65,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [66,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [67,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [68,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [69,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [70,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [71,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [72,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [73,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [74,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [75,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [76,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [77,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [78,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [79,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [80,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [81,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [82,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [83,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [84,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [85,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [86,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [87,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [88,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [89,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [90,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [91,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [92,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [93,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [94,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [176,0,0], thread: [95,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [96,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [97,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [98,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [99,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [100,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [101,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [102,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [103,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [104,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [105,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [106,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [107,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [108,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [109,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [110,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [111,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [112,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [113,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [114,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [115,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [116,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [117,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [118,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [119,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [120,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [121,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [122,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [123,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [124,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [125,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [126,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ../aten/src/ATen/native/cuda/IndexKernel.cu:92: operator(): block: [170,0,0], thread: [127,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
#   0% 0/65 [00:04<?, ?it/s]
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/cfg/__init__.py", line 249, in entrypoint
#     getattr(model, mode)(verbose=True, **overrides)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/model.py", line 207, in train
#     self.trainer.train()
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/trainer.py", line 183, in train
#     self._do_train(int(os.getenv("RANK", -1)), world_size)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/trainer.py", line 302, in _do_train
#     self.loss, self.loss_items = self.criterion(preds, batch)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/v8/detect/train.py", line 76, in criterion
#     return self.compute_loss(preds, batch)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/v8/detect/train.py", line 174, in __call__
#     _, target_bboxes, target_scores, fg_mask, _ = self.assigner(
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/utils/tal.py", line 94, in forward
#     mask_pos, align_metric, overlaps = self.get_pos_mask(pd_scores, pd_bboxes, gt_labels, gt_bboxes, anc_points,
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/utils/tal.py", line 113, in get_pos_mask
#     align_metric, overlaps = self.get_box_metrics(pd_scores, pd_bboxes, gt_labels, gt_bboxes)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/utils/tal.py", line 131, in get_box_metrics
#     overlaps = bbox_iou(gt_bboxes.unsqueeze(2), pd_bboxes.unsqueeze(1), xywh=False, CIoU=True).squeeze(3).clamp(0)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/utils/metrics.py", line 82, in bbox_iou
#     inter = (b1_x2.minimum(b2_x2) - b1_x1.maximum(b2_x1)).clamp(0) * \
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Sentry is attempting to send 2 pending events
# Waiting up to 2 seconds
# Press Ctrl-C to quit

# %% [markdown]
# # Test and run

# %%
# Ensure you have the required libraries installed
# !pip install ultralytics opencv-python-headless

from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow
from google.colab import files
import io
import numpy as np
from IPython.display import display, Javascript
from base64 import b64encode

# Load the YOLOv8 model
model = YOLO('/content/runs/detect/train/weights/best.pt')  # Replace with your trained model path

# Upload video file
# uploaded = files.upload()
# video_file = next(iter(uploaded))

# Initialize video capture
cap = cv2.VideoCapture('/content/gdrive/MyDrive/dataset.mov')

if not cap.isOpened():
    print("Error: Could not open video stream.")
    exit()

# Function to encode frame as JPEG
def encode_frame(frame):
    _, buffer = cv2.imencode('.jpg', frame)
    return b64encode(buffer).decode('utf-8')

# JavaScript to update image
js_code = """
    function updateImage(frameData) {
        document.getElementById('video').src = 'data:image/jpeg;base64,' + frameData;
    }
"""

# Display initial setup
display(Javascript(js_code))
display(Javascript('document.getElementById("output").innerHTML += \'<img id="video" style="width: 100%"/>\';'))

while True:
    ret, frame = cap.read()
    if not ret:
        print("Failed to grab frame.")
        break

    frame = cv2.resize(frame, (1050, 540))

    # Perform helmet detection
    results = model(frame)

    # Extract bounding boxes and labels from the results
    for result in results:
        boxes = result.boxes.xyxy.cpu().numpy()
        confidences = result.boxes.conf.cpu().numpy()
        class_ids = result.boxes.cls.cpu().numpy().astype(int)

        for i, box in enumerate(boxes):
            x1, y1, x2, y2 = map(int, box)
            confidence = confidences[i]
            class_id = class_ids[i]
            label = model.names[class_id]

            # Draw bounding box and label
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(frame, f"{label}: {confidence:.2f}", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Encode and display the frame
    encoded_frame = encode_frame(frame)
    display(Javascript(f'updateImage("{encoded_frame}")'))

    # Add a small delay to control frame rate
    from time import sleep
    sleep(0.1)

# Release resources
cap.release()
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.10/dist-packages (8.0.20)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.4.1+cu121)
# Requirement already satisfied: torchvision>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.19.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.5)
# Requirement already satisfied: tensorboard>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.17.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from ultralytics) (7.34.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: thop>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: sentry-sdk in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->ultralytics) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->ultralytics) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->ultralytics) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->ultralytics) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->ultralytics) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->ultralytics) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,<5.0.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->ultralytics) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->ultralytics) (71.0.4)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->ultralytics) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->ultralytics) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->ultralytics) (3.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->ultralytics) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->ultralytics) (2024.6.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython->ultralytics) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->ultralytics) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->ultralytics) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->ultralytics) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->ultralytics) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->ultralytics) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->ultralytics) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->ultralytics) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->ultralytics) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->ultralytics) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->ultralytics) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ultralytics) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7.0->ultralytics) (1.3.0)
# /usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py:332: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(file, map_location='cpu')  # load
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-43c2a124eba6> in <cell line: 21>()
#      19
#      20 # Initialize video capture
# ---> 21 cap = cv2.VideoCapture('/content/gdrive/MyDrive/dataset.mov')
#      22
#      23 if not cap.isOpened():
#
# KeyboardInterrupt:

# %% [markdown]
# # Image Gen

# %%
import cv2
import time
cpt = 0
maxFrames = 10000 # if you want 5 frames only.

count=0
cap=cv2.VideoCapture('/content/gdrive/MyDrive/dataset-1.mov')
while cpt < maxFrames:
    ret, frame = cap.read()
    count += 1
    if count % 25 != 0:
        continue
    frame=cv2.resize(frame,(1080,500))
    time.sleep(0.001)
    # frame=cv2.flip(frame,1)
    # cv2.imshow("test window", frame) # show image in window
    cv2.imwrite(r"/content/dataset-1/%d_person.jpg" %cpt, frame)
    cpt += 1
    if cv2.waitKey(5)&0xFF==27:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-8-f2726953ff5b> in <cell line: 8>()
#      11     if count % 25 != 0:
#      12         continue
# ---> 13     frame=cv2.resize(frame,(1080,500))
#      14     time.sleep(0.001)
#      15     # frame=cv2.flip(frame,1)
#
# error: OpenCV(4.10.0) /io/opencv/modules/imgproc/src/resize.cpp:4152: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
# !zip -r weights.zip /content/runs/detect/train3
# Out:
#   adding: content/runs/detect/train3/ (stored 0%)
#   adding: content/runs/detect/train3/confusion_matrix.png (deflated 30%)
#   adding: content/runs/detect/train3/R_curve.png (deflated 13%)
#   adding: content/runs/detect/train3/args.yaml (deflated 51%)
#   adding: content/runs/detect/train3/P_curve.png (deflated 21%)
#   adding: content/runs/detect/train3/F1_curve.png (deflated 13%)
#   adding: content/runs/detect/train3/PR_curve.png (deflated 21%)
#   adding: content/runs/detect/train3/results.csv (deflated 86%)
#   adding: content/runs/detect/train3/weights/ (stored 0%)
#   adding: content/runs/detect/train3/weights/last.pt (deflated 8%)
#   adding: content/runs/detect/train3/weights/best.pt (deflated 8%)
#   adding: content/runs/detect/train3/results.png (deflated 11%)
#   adding: content/runs/detect/train3/events.out.tfevents.1728807883.5348abc71617.16404.0 (deflated 72%)
